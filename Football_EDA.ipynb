# %% [markdown]
# # **Football Mathces Datasets**
#
# ### **Data Description:**
# - These datasets include the football matches results of the last 10 seasons plus the current season.
# - These results are for the English, German, Spanish, Italic, French, Portuguese, Dutch, and Saudi leagues
#
# ### **Data Dictionary:**
# The English, German, Spanish, Italic, French, Portuguese, And Dutch leagues shares these 10 columns
#
# Key to results data:
# - League = Referese to the country's league
# - Wk = The week of the game during the season
# - Day= The Day of the game during the season
# - Date = The Date of the football game
# - Time = The Timing of the football game
# - Home = Home team
# - Home = Away team
# - Score = Game Score (Number of goals for each team)
# - Attendance = Total attendance of the game
# - Venue = Stadium Name
# - Referee = Referee Name
# - Match Report = A report for the match (If there are important information. For examplem a team forfeit from a game)
# - Notes = Notes

# %%
import glob
import os
import pandas as pd
import numpy as py

# %%
E2021=pd.read_csv('Data/English/E2021.csv')

# %%
E2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Wk            380 non-null    int64
#  1   Day           380 non-null    object
#  2   Date          380 non-null    object
#  3   Time          380 non-null    object
#  4   Home          380 non-null    object
#  5   xG            380 non-null    float64
#  6   Score         380 non-null    object
#  7   xG.1          380 non-null    float64
#  8   Away          380 non-null    object
#  9   Attendance    32 non-null     float64
#  10  Venue         380 non-null    object
#  11  Referee       380 non-null    object
#  12  Match Report  380 non-null    object
#  13  Notes         0 non-null      float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 41.7+ KB

# %%
SP2022=pd.read_csv('Data/Spanish/SP2015.csv')

# %%
SP2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Wk            380 non-null    int64
#  1   Day           380 non-null    object
#  2   Date          380 non-null    object
#  3   Time          380 non-null    object
#  4   Home          380 non-null    object
#  5   Score         380 non-null    object
#  6   Away          380 non-null    object
#  7   Attendance    380 non-null    int64
#  8   Venue         380 non-null    object
#  9   Referee       380 non-null    object
#  10  Match Report  380 non-null    object
#  11  Notes         0 non-null      float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 35.8+ KB

# %%
I2022=pd.read_csv('Data/Italic/I2022.csv')

# %%
I2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Wk            380 non-null    int64
#  1   Day           380 non-null    object
#  2   Date          380 non-null    object
#  3   Time          280 non-null    object
#  4   Home          380 non-null    object
#  5   xG            245 non-null    float64
#  6   Score         246 non-null    object
#  7   xG.1          245 non-null    float64
#  8   Away          380 non-null    object
#  9   Attendance    224 non-null    float64
#  10  Venue         290 non-null    object
#  11  Referee       246 non-null    object
#  12  Match Report  376 non-null    object
#  13  Notes         5 non-null      object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 41.7+ KB

# %%
#Identify common features for all datasets
Features = ['League', 'Wk', 'Day', 'Date', 'Time', 'Home', 'Score', 'Away',
       'Attendance', 'Venue', 'Referee', 'Match Report', 'Notes']
len(Features)
# Out:
# 13

# %%
#This function is for handelling the unwanted features
def my_function(g):
    c=[]
    for (columnName, columnData) in g.iteritems():
        z=columnName in Features
        if z == False:
            c.append(columnName)
    print(c)        
    g.drop(c, axis=1 , inplace = True)

# %%
#Read Leagues datasets and mergethem in a dataset for each league
all_files0 = glob.glob('Data/Spanish' + "/*.csv")
spanish = pd.concat(map(pd.read_csv, all_files0), ignore_index=True, sort=False)
spanish.insert(0,'League', 'SP')
my_function(spanish)

all_files1 = glob.glob('Data/Portuguese' + "/*.csv")
portuguese = pd.concat(map(pd.read_csv, all_files1), ignore_index=True, sort=False)
portuguese.insert(0,'League', 'P')
my_function(portuguese)

all_files2 = glob.glob('Data/Italic' + "/*.csv")
italic = pd.concat(map(pd.read_csv, all_files2), ignore_index=True, sort=False )
italic.insert(0,'League', 'IT')
my_function(italic)

all_files3 = glob.glob('Data/French' + "/*.csv")
french = pd.concat(map(pd.read_csv, all_files3), ignore_index=True, sort=False)
french.insert(0,'League', 'FL')
my_function(french)

all_files4 = glob.glob('Data/German' + "/*.csv")
german = pd.concat(map(pd.read_csv, all_files4), ignore_index=True, sort=False)
german.insert(0,'League', 'BL')
my_function(german)

all_files5 = glob.glob('Data/English' + "/*.csv")
english = pd.concat(map(pd.read_csv, all_files5), ignore_index=True, sort=False)
english.insert(0,'League', 'PL')
my_function(english)

all_files6 = glob.glob('Data/Dutch' + "/*.csv")
dutch = pd.concat(map(pd.read_csv, all_files6), ignore_index=True, sort=False)
dutch.insert(0,'League', 'D')
my_function(dutch)

all_files7 = glob.glob('Data/Saudi' + "/*.csv")
saudi = pd.concat(map(pd.read_csv, all_files7), ignore_index=True, sort=False)
saudi.insert(0,'League', 'SPL')
my_function(saudi)
# Out:
# ['xG', 'xG.1']
# ['Round']
# ['xG', 'xG.1']
# ['Round', 'xG', 'xG.1']
# ['Round', 'xG', 'xG.1']
# ['xG', 'xG.1']
# ['Round']
# []

# %%
df = pd.concat([spanish, portuguese, italic, french, german, english, dutch, saudi], ignore_index=True, sort=False)

# %%
df.sample(30)
# Out:
#       League    Wk  Day        Date           Time            Home Score  \
# 15927     BL  23.0  Sun  2012-02-26            NaN   Bayern Munich   2–0
# 11426     IT  28.0  Sun  2022-03-06  15:00 (17:00)      Fiorentina   NaN
# 5450       P  28.0  Fri  2016-04-01  20:30 (22:30)         Benfica   5–1
# 2161      SP  27.0  Sat  2017-03-11  16:15 (18:15)         Sevilla   1–1
# 11391     IT  25.0  Sat  2022-02-12  15:00 (17:00)           Lazio   3–0
# 7949      IT  22.0  Sun  2013-01-27            NaN       Sampdoria   6–0
# 14175     FL  37.0  Fri  2018-05-11  20:45 (21:45)        Guingamp   3–3
# 13250     FL  21.0  Fri  2017-01-20  20:45 (22:45)          Bastia   1–1
# 3871      SP   8.0  Sat  2021-10-02  16:15 (17:15)        Mallorca   1–0
# 19840     PL  33.0  Wed  2013-05-08            NaN         Chelsea   2–2
# 15886     BL  19.0  Sat  2012-01-28            NaN   Bayern Munich   2–0
# 4344       P  21.0  Sun  2012-03-04            NaN        Feirense   1–1
# 11470     IT  32.0  Sun  2022-04-10            NaN          Napoli   NaN
# 16338     BL   1.0  Sat  2013-08-10            NaN    Braunschweig   0–1
# 2572      SP  30.0  Sat  2018-03-31  17:30 (19:30)      Las Palmas   0–3
# 19373     PL  28.0  Sat  2012-03-10            NaN     Aston Villa   1–0
# 1448      SP  31.0  Sun  2015-04-12  21:00 (22:00)         Córdoba   0–2
# 11464     IT  32.0  Sun  2022-04-10            NaN          Torino   NaN
# 21473     PL  10.0  Sat  2017-10-28  15:00 (17:00)  Crystal Palace   2–2
# 16392     BL   7.0  Sat  2013-09-28            NaN      Leverkusen   2–0
# 2356      SP   8.0  Sun  2017-10-15  16:15 (17:15)          Girona   1–2
# 7899      IT  17.0  Sun  2012-12-16            NaN          Chievo   1–0
# 8815      IT  33.0  Wed  2015-04-29  20:45 (21:45)        Juventus   3–2
# 3982      SP  19.0  Fri  2021-12-31  16:15 (18:15)        Valencia   1–2
# 3609      SP  20.0  Sat  2021-01-23  18:30 (20:30)   Real Sociedad   2–2
# 12231     FL  33.0  Fri  2013-04-19            NaN     Montpellier   1–2
# 4237       P   8.0  Fri  2011-10-21            NaN           Paços   2–0
# 27983    SPL   4.0  Fri  2020-11-06          15:35           Damac   0–0
# 19993     PL  14.0  Wed  2013-12-04            NaN    Swansea City   3–0
# 9185      IT  32.0  Sun  2016-04-10  12:30 (13:30)          Empoli   2–0
#
#                 Away  Attendance                                 Venue  \
# 15927     Schalke 04         NaN                                   NaN
# 11426  Hellas Verona         NaN                Stadio Artemio Franchi
# 5450           Braga     61042.0     Estádio do Sport Lisboa e Benfica
# 2161         Leganés     31738.0         Estadio Ramón Sánchez Pizjuán
# 11391        Bologna         NaN                       Stadio Olimpico
# 7949         Pescara         NaN                                   NaN
# 14175      Marseille     18378.0                    Stade du Roudourou
# 13250           Nice      9757.0                   Stade Armand Césari
# 3871         Levante     11803.0                      Iberostar Estadi
# 19840      Tottenham         NaN                                   NaN
# 15886      Wolfsburg         NaN                                   NaN
# 4344       Académica         NaN           Estádio Marcolino de Castro
# 11470     Fiorentina         NaN                                   NaN
# 16338  Werder Bremen         NaN                                   NaN
# 2572     Real Madrid     22942.0               Estadio de Gran Canaria
# 19373         Fulham         NaN                                   NaN
# 1448           Elche     14164.0                Estadio Nuevo Arcángel
# 11464          Milan         NaN                                   NaN
# 21473       West Ham     25242.0                         Selhurst Park
# 16392    Hannover 96         NaN                                   NaN
# 2356      Villarreal      9935.0         Estadi Municipal de Montilivi
# 7899            Roma         NaN                                   NaN
# 8815      Fiorentina     37503.0                       Allianz Stadium
# 3982        Espanyol     29566.0                   Estadio de Mestalla
# 3609           Betis         NaN           Estadio Municipal de Anoeta
# 12231           Lyon         NaN   Stade de la Mosson et du Mondial 98
# 4237       Académica         NaN           Estádio da Capital do Móvel
# 27983     Al-Faisaly        40.0  Prince Sultan bin Abdul Aziz Stadium
# 19993  Newcastle Utd         NaN                                   NaN
# 9185      Fiorentina      9651.0               Stadio Carlo Castellani
#
#                            Referee  Match Report Notes
# 15927               Michael Weiner  Match Report   NaN
# 11426                          NaN  Head-to-Head   NaN
# 5450   Nuno Miguel Serrano Almeida  Match Report   NaN
# 2161                 José González  Match Report   NaN
# 11391              Marco Piccinini  Match Report   NaN
# 7949                  Dino Tommasi  Match Report   NaN
# 14175               Amaury Delerue  Match Report   NaN
# 13250               Clément Turpin  Match Report   NaN
# 3871               Alejandro Muñíz  Match Report   NaN
# 19840                    Mike Dean  Match Report   NaN
# 15886                 Felix Zwayer  Match Report   NaN
# 4344                 Cosme Machado  Match Report   NaN
# 11470                          NaN  Head-to-Head   NaN
# 16338                Deniz Aytekin  Match Report   NaN
# 2572                Pablo González  Match Report   NaN
# 19373                     Jon Moss  Match Report   NaN
# 1448                 Iñaki Bikandi  Match Report   NaN
# 11464                          NaN  Head-to-Head   NaN
# 21473                Robert Madley  Match Report   NaN
# 16392               Wolfgang Stark  Match Report   NaN
# 2356              Carlos del Cerro  Match Report   NaN
# 7899                Mauro Bergonzi  Match Report   NaN
# 8815                    Luca Banti  Match Report   NaN
# 3982                  José Sánchez  Match Report   NaN
# 3609                    César Soto  Match Report   NaN
# 12231            Sébastien Moreira  Match Report   NaN
# 4237                  Duarte Gomes  Match Report   NaN
# 27983        Sultan Sanat Al Harbi  Match Report   NaN
# 19993                  Howard Webb  Match Report   NaN
# 9185                Antonio Damato  Match Report   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28356 entries, 0 to 28355
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   League        28356 non-null  object
#  1   Wk            28226 non-null  float64
#  2   Day           28355 non-null  object
#  3   Date          28355 non-null  object
#  4   Time          20757 non-null  object
#  5   Home          28355 non-null  object
#  6   Score         27292 non-null  object
#  7   Away          28355 non-null  object
#  8   Attendance    17048 non-null  float64
#  9   Venue         25230 non-null  object
#  10  Referee       27208 non-null  object
#  11  Match Report  28335 non-null  object
#  12  Notes         322 non-null    object
# dtypes: float64(2), object(11)
# memory usage: 2.8+ MB
